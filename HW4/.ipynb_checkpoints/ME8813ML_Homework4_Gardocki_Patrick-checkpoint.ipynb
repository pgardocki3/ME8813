# %% [markdown]
# ## Importing Data

# %%
#% matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# Import Data
url = 'https://raw.githubusercontent.com/pgardocki3/ME8813ML/master/HW4/HW4Dataset.csv'
df = pd.read_csv(url)
df.drop('Unnamed: 0', inplace=True, axis=1) 
df.head()

X_train, X_test= train_test_split(df, test_size=0.33, random_state=42)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
print(df.shape)
print(X_test.shape)
# Out:
# (8900, 15)
# (2937, 15)

# %% [markdown]
# ## Scree-Plot

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scalar = StandardScaler()
scaled_df = df.copy()
scaled_df = pd.DataFrame(scalar.fit_transform(scaled_df),columns=scaled_df.columns)

# Perform PCA
pca = PCA(n_components=15)
pca_fit = pca.fit(scaled_df)

PC_values = np.arange(pca.n_components_) + 1
plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()
print(pca.explained_variance_ratio_)
# Out:
# [0.08468407 0.07398296 0.06999707 0.06775147 0.06737666 0.0666653
#  0.06631915 0.0660598  0.065598   0.06487405 0.0642329  0.06411427
#  0.06271662 0.05962846 0.05599922]

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans


sse = []
minClust = 1
maxClust = 15
for i in range(minClust, maxClust):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(df)
    sse.append(kmeans.inertia_)


plt.figure(figsize=(15, 6))
plt.plot(range(minClust, maxClust), sse)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('sse')
plt.xticks(np.arange(minClust, maxClust, 1))
plt.grid()
plt.show()

# %% [markdown]
# ## Gaussian Mixture Modeling

# %%
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ## AutoEncoder

# %%
from keras.layers import Dense,Conv2D,MaxPooling2D,UpSampling2D
from keras import Input, Model
import numpy as np
import matplotlib.pyplot as plt

encoding_dim = 5 
input_img = Input(shape=(15,0))


# Encoder
input_dim = Input(shape = (15, ))
encoded1 = Dense(10, activation = 'relu')(input_dim)
encoded2 = Dense(5, activation = 'relu')(encoded1)
encoded3 = Dense(4, activation = 'relu')(encoded2)
# Decoder
decoded1 = Dense(5, activation = 'relu')(encoded3)
decoded2 = Dense(10, activation = 'relu')(decoded1)
decoded3 = Dense(15, activation = 'relu')(decoded2)

autoencoder = Model(inputs = input_dim, outputs = decoded3)
autoencoder.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])
autoencoder.summary()


history = autoencoder.fit(X_train, X_train,epochs=10,batch_size=6,shuffle=True,validation_data=(X_test, X_test))


#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Model: "model_131"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_96 (InputLayer)       [(None, 15)]              0
#
#  dense_136 (Dense)           (None, 10)                160
#
#  dense_137 (Dense)           (None, 5)                 55
#
#  dense_138 (Dense)           (None, 4)                 24
#
#  dense_139 (Dense)           (None, 5)                 25
#
#  dense_140 (Dense)           (None, 10)                60
#
#  dense_141 (Dense)           (None, 15)                165
#
# =================================================================
# Total params: 489
# Trainable params: 489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.1140 - mse: 0.1140 - val_loss: 0.1074 - val_mse: 0.1074
# Epoch 2/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0962 - mse: 0.0962 - val_loss: 0.0821 - val_mse: 0.0821
# Epoch 3/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0815 - mse: 0.0815 - val_loss: 0.0801 - val_mse: 0.0801
# Epoch 4/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0800 - mse: 0.0800 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 5/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0796 - mse: 0.0796 - val_loss: 0.0793 - val_mse: 0.0793
# Epoch 6/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0794 - mse: 0.0794 - val_loss: 0.0790 - val_mse: 0.0790
# Epoch 7/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0792 - mse: 0.0792 - val_loss: 0.0787 - val_mse: 0.0787
# Epoch 8/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0790 - mse: 0.0790 - val_loss: 0.0785 - val_mse: 0.0785
# Epoch 9/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0788 - mse: 0.0788 - val_loss: 0.0784 - val_mse: 0.0784
# Epoch 10/10
# 994/994 [==============================] - 2s 2ms/step - loss: 0.0787 - mse: 0.0787 - val_loss: 0.0783 - val_mse: 0.0783
